# %% [markdown]
# # 🏥 HealthBot: AI-Powered Patient Education System
#
# ## Capstone Project
#
# ### Technologies Used
# - Python 3.11
# - LangGraph
# - LangChain
# - Cohere
# - Tavily Search API
#
# ---
#
# This project educates patients about health conditions by:
# 1. Searching trusted medical resources.
# 2. Generating a patient-friendly summary.
# 3. Creating a quiz.
# 4. Evaluating the patient's understanding.

# %%
from graph import healthbot_app

# %%
initial_state = {
    "topic": "",
    "search_results": {},
    "summary": "",
    "quiz_question": "",
    "user_answer": "",
    "grade": "",
    "feedback": "",
    "continue_learning": False,
}

# %%
healthbot_app.invoke(initial_state)
# Out:
# --- Welcome to MediTech HealthBot ---
#
# [Searching for reputable medical information on 'High bp'...]
#
# --- Summary ---
# High blood pressure, also known as hypertension, is a common condition that affects the arteries in your body. It occurs when the force of your blood pushing against the artery walls is consistently too high. Blood pressure is measured in millimeters of mercury (mm Hg), and a reading of 130/80 mm Hg or higher is generally considered hypertension. When you have high blood pressure, your heart has to work harder to pump blood, which can lead to various health complications.
#
# ...
